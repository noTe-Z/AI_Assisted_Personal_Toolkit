# %%
import pandas as pd

df = pd.read_csv('cvpr2024_papers_detailed.csv')
df.head()
# Out:
#                                          Paper Title  \
# 0  Unmixing Diffusion for Self-Supervised Hypersp...
# 1                 Seeing the World through Your Eyes
# 2  DPMesh: Exploiting Diffusion Prior for Occlude...
# 3                           Ungeneralizable Examples
# 4  LaneCPP: Continuous 3D Lane Detection using Ph...
#
#                                              Authors  \
# 0  Haijin Zeng,\n\n\n\nJiezhang Cao,\n\n\n\nKai Z...
# 1  Hadi Alzayer,\n\n\n\nKevin Zhang,\n\n\n\nBrand...
# 2  Yixuan Zhu,\n\n\n\nAo Li,\n\n\n\nYansong Tang,...
# 3                    Jingwen Ye,\n\n\n\nXinchao Wang
# 4  Maximilian Pittner,\n\n\n\nJoel Janai,\n\n\n\n...
#
#                                             PDF Link  \
# 0  https://openaccess.thecvf.com//content/CVPR202...
# 1  https://openaccess.thecvf.com//content/CVPR202...
# 2  https://openaccess.thecvf.com//content/CVPR202...
# 3  https://openaccess.thecvf.com//content/CVPR202...
# ...
